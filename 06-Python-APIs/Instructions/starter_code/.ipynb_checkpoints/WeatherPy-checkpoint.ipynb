# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# #Analysis
# (1) The temperature at the Southern Hemisphere seems more favorable and can be attributed to the presence of more aquatic habitat than terrestial habitat
# (2) There is also a correlation between Temperature and Latitude. As latitude moves away from equator, temperature decreases.
# (3) Wind speed is controlled by other factors other than latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import requests
import json
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %%
# save config information.
url ="http://api.openweathermap.org/data/2.5/weather?"
units="imperial"

# %%
new_city=[]
lat=[]         
lng=[]           
max_temp=[]    
humidity =[]     
cloudiness =[] 
wind_speed =[]   
country =[]      
date  =[]   
index_counter=0
set_counter=1

query_url=(f"{url}appid={weather_api_key}&units={units}&q=")
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=36d27378545f7daafa9d3ff4e9ef2e7a&units=imperial&q='

# %%
print(f"Beginning Data Retrieval")
print(f"------------------------")

for city in cities:
    try:
        time.sleep(1)

        response=requests.get(query_url +city)
        json_response=response.json()
        #print(json.dumps(json_response, indent=4, sort_keys=True))
        new_city.append(json_response["name"])
        lat.append(json_response["coord"]["lat"])
        lng.append(json_response["coord"]["lon"])
        max_temp.append(json_response["main"]["temp_max"])
        humidity.append(json_response["main"]["humidity"])
        cloudiness.append(json_response["clouds"]["all"])
        wind_speed.append(json_response["wind"]["speed"])
        country.append(json_response["sys"]["country"])
        date.append(json_response["dt"])
        if index_counter>49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
        
        print(f"Processing {index_counter} of set {set_counter}:{city}")
    except KeyError:
        print("Another one!")
print(f"-------------------------------")
print(f"Ending Data Retrieval")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing 1 of set 1:khatanga
# Processing 2 of set 1:mao
# Processing 3 of set 1:asau
# Processing 4 of set 1:broome
# Processing 5 of set 1:rikitea
# Processing 6 of set 1:balikpapan
# Processing 7 of set 1:codrington
# Processing 8 of set 1:punta arenas
# Processing 9 of set 1:bluff
# Processing 10 of set 1:iqaluit
# Processing 11 of set 1:busselton
# Processing 12 of set 1:atuona
# Processing 13 of set 1:cape town
# Processing 14 of set 1:new norfolk
# Processing 15 of set 1:jamestown
# Processing 16 of set 1:hofn
# Processing 17 of set 1:kodiak
# Processing 18 of set 1:provideniya
# Processing 19 of set 1:tenenkou
# Processing 20 of set 1:kapaa
# Processing 21 of set 1:hamilton
# Processing 22 of set 1:muzhi
# Processing 23 of set 1:victoria
# Processing 24 of set 1:port alfred
# Processing 25 of set 1:hithadhoo
# Processing 26 of set 1:mahebourg
# Another one!
# Processing 27 of set 1:rimbey
# Processing 28 of set 1:barrow
# Processing 29 of set 1:mar del plata
# Processing 30 of set 1:kruisfontein
# Processing 31 of set 1:san patricio
# Processing 32 of set 1:cap malheureux
# Processing 33 of set 1:mataura
# Another one!
# Processing 34 of set 1:puerto ayora
# Processing 35 of set 1:muravlenko
# Processing 36 of set 1:arraial do cabo
# Processing 37 of set 1:whitehorse
# Processing 38 of set 1:torbay
# Processing 39 of set 1:rock sound
# Processing 40 of set 1:tazovskiy
# Processing 41 of set 1:vaini
# Processing 42 of set 1:avarua
# Processing 43 of set 1:ushuaia
# Another one!
# Processing 44 of set 1:sicamous
# Processing 45 of set 1:albany
# Processing 46 of set 1:kenai
# Another one!
# Processing 47 of set 1:pukhrayan
# Processing 48 of set 1:husavik
# Processing 49 of set 1:beringovskiy
# Processing 50 of set 1:egvekinot
# Another one!
# Processing 0 of set 2:bredasdorp
# Processing 1 of set 2:tiksi
# Processing 2 of set 2:hobart
# Processing 3 of set 2:hilo
# Processing 4 of set 2:namibe
# Processing 5 of set 2:lovozero
# Another one!
# Processing 6 of set 2:korla
# Processing 7 of set 2:naze
# Processing 8 of set 2:san quintin
# Processing 9 of set 2:east london
# Processing 10 of set 2:puerto colombia
# Processing 11 of set 2:longyearbyen
# Processing 12 of set 2:maniitsoq
# Processing 13 of set 2:faanui
# Processing 14 of set 2:yuzhno-kurilsk
# Processing 15 of set 2:coruripe
# Processing 16 of set 2:qaanaaq
# Processing 17 of set 2:yulara
# Processing 18 of set 2:salekhard
# Processing 19 of set 2:souillac
# Processing 20 of set 2:butaritari
# Processing 21 of set 2:anito
# Processing 22 of set 2:yellowknife
# Processing 23 of set 2:georgetown
# Processing 24 of set 2:villaviciosa
# Another one!
# Processing 25 of set 2:freetown
# Processing 26 of set 2:pital
# Another one!
# Processing 27 of set 2:cayenne
# Another one!
# Processing 28 of set 2:pemangkat
# Another one!
# Processing 29 of set 2:san luis jilotepeque
# Processing 30 of set 2:tieli
# Processing 31 of set 2:buraydah
# Processing 32 of set 2:bethel
# Processing 33 of set 2:saint george
# Processing 34 of set 2:tuktoyaktuk
# Processing 35 of set 2:channel-port aux basques
# Processing 36 of set 2:high level
# Processing 37 of set 2:klaksvik
# Processing 38 of set 2:ponta do sol
# Processing 39 of set 2:port elizabeth
# Processing 40 of set 2:hermanus
# Processing 41 of set 2:hasaki
# Processing 42 of set 2:lebu
# Processing 43 of set 2:shchors
# Processing 44 of set 2:atar
# Processing 45 of set 2:grindavik
# Processing 46 of set 2:manzhouli
# Processing 47 of set 2:terrace bay
# Processing 48 of set 2:zhigansk
# Processing 49 of set 2:yatou
# Processing 50 of set 2:geraldton
# Processing 0 of set 3:tondano
# Processing 1 of set 3:nikolskoye
# Processing 2 of set 3:bedford
# Another one!
# Processing 3 of set 3:petropavlovsk-kamchatskiy
# Processing 4 of set 3:vardo
# Processing 5 of set 3:matamoros
# Processing 6 of set 3:kovdor
# Processing 7 of set 3:okhotsk
# Processing 8 of set 3:tuatapere
# Processing 9 of set 3:adwa
# Processing 10 of set 3:umm kaddadah
# Processing 11 of set 3:alice springs
# Processing 12 of set 3:saskylakh
# Processing 13 of set 3:saint-philippe
# Processing 14 of set 3:abha
# Processing 15 of set 3:esperance
# Processing 16 of set 3:faya
# Processing 17 of set 3:tanout
# Processing 18 of set 3:alekseyevka
# Processing 19 of set 3:bonavista
# Processing 20 of set 3:timizart
# Another one!
# Another one!
# Processing 21 of set 3:shimoda
# Processing 22 of set 3:nyurba
# Processing 23 of set 3:dikson
# Processing 24 of set 3:carnarvon
# Another one!
# Processing 25 of set 3:masty
# Processing 26 of set 3:castro
# Processing 27 of set 3:aklavik
# Processing 28 of set 3:constitucion
# Processing 29 of set 3:acajutla
# Processing 30 of set 3:namatanai
# Processing 31 of set 3:iquitos
# Processing 32 of set 3:stornoway
# Another one!
# Processing 33 of set 3:touros
# Processing 34 of set 3:manakara
# Processing 35 of set 3:humaita
# Processing 36 of set 3:yerbogachen
# Another one!
# Processing 37 of set 3:tasiilaq
# Processing 38 of set 3:kolosovka
# Processing 39 of set 3:katsuura
# Processing 40 of set 3:tchollire
# Processing 41 of set 3:labytnangi
# Processing 42 of set 3:sandpoint
# Another one!
# Processing 43 of set 3:lagoa
# Processing 44 of set 3:hay river
# Processing 45 of set 3:voi
# Another one!
# Processing 46 of set 3:airai
# Processing 47 of set 3:lata
# Another one!
# Processing 48 of set 3:teguise
# Processing 49 of set 3:kavaratti
# Processing 50 of set 3:borba
# Processing 0 of set 4:kilimatinde
# Processing 1 of set 4:ribeira grande
# Processing 2 of set 4:fairbanks
# Processing 3 of set 4:mitsamiouli
# Processing 4 of set 4:arona
# Processing 5 of set 4:harper
# Processing 6 of set 4:khislavichi
# Processing 7 of set 4:padang
# Processing 8 of set 4:kadoma
# Processing 9 of set 4:westport
# Processing 10 of set 4:chokurdakh
# Processing 11 of set 4:sabha
# Processing 12 of set 4:lavrentiya
# Another one!
# Processing 13 of set 4:maldonado
# Processing 14 of set 4:mount gambier
# Processing 15 of set 4:opuwo
# Processing 16 of set 4:noumea
# Processing 17 of set 4:clyde river
# Another one!
# Processing 18 of set 4:caravelas
# Processing 19 of set 4:walvis bay
# Processing 20 of set 4:ternate
# Processing 21 of set 4:ozinki
# Processing 22 of set 4:sao joao da barra
# Processing 23 of set 4:bundaberg
# Another one!
# Processing 24 of set 4:grand gaube
# Processing 25 of set 4:sao filipe
# Processing 26 of set 4:nalut
# Another one!
# Processing 27 of set 4:ulaanbaatar
# Processing 28 of set 4:cabo san lucas
# Processing 29 of set 4:manokwari
# Another one!
# Processing 30 of set 4:povenets
# Processing 31 of set 4:bilma
# Processing 32 of set 4:kakuda
# Processing 33 of set 4:muli
# Processing 34 of set 4:priiskovyy
# Processing 35 of set 4:vestmannaeyjar
# Processing 36 of set 4:aripuana
# Processing 37 of set 4:san cristobal
# Processing 38 of set 4:avera
# Processing 39 of set 4:zhangjiakou
# Another one!
# Processing 40 of set 4:mogadishu
# Processing 41 of set 4:abu kamal
# Processing 42 of set 4:sitka
# Processing 43 of set 4:chuy
# Processing 44 of set 4:cidreira
# Processing 45 of set 4:nome
# Processing 46 of set 4:deer lake
# Processing 47 of set 4:asfi
# Processing 48 of set 4:florianopolis
# Processing 49 of set 4:mahmudabad
# Processing 50 of set 4:labuhan
# Processing 0 of set 5:pisco
# Processing 1 of set 5:progreso
# Processing 2 of set 5:kavieng
# Another one!
# Processing 3 of set 5:kailua
# Processing 4 of set 5:verkhnyaya inta
# Processing 5 of set 5:nioro
# Processing 6 of set 5:sagar
# Another one!
# Processing 7 of set 5:kuytun
# Processing 8 of set 5:kurayoshi
# Processing 9 of set 5:cedar city
# Processing 10 of set 5:christchurch
# Processing 11 of set 5:sorland
# Processing 12 of set 5:kasempa
# Processing 13 of set 5:soyo
# Processing 14 of set 5:codajas
# Processing 15 of set 5:tucuman
# Processing 16 of set 5:telimele
# Processing 17 of set 5:arkhangelsk
# Processing 18 of set 5:adrar
# Another one!
# Another one!
# Processing 19 of set 5:fenelon falls
# Processing 20 of set 5:leshukonskoye
# Processing 21 of set 5:lasa
# Processing 22 of set 5:lufilufi
# Processing 23 of set 5:upernavik
# Processing 24 of set 5:thompson
# Processing 25 of set 5:uthal
# Processing 26 of set 5:nanakuli
# Another one!
# Processing 27 of set 5:broken hill
# Processing 28 of set 5:college
# Processing 29 of set 5:jerez
# Processing 30 of set 5:ca mau
# Processing 31 of set 5:neryungri
# Processing 32 of set 5:sheregesh
# Processing 33 of set 5:cherskiy
# Processing 34 of set 5:pevek
# Processing 35 of set 5:coihaique
# Processing 36 of set 5:maragogi
# Processing 37 of set 5:houma
# Processing 38 of set 5:pangnirtung
# Processing 39 of set 5:alvarado
# Processing 40 of set 5:honningsvag
# Processing 41 of set 5:abonnema
# Processing 42 of set 5:pimentel
# Processing 43 of set 5:rio gallegos
# Processing 44 of set 5:puerto carreno
# Processing 45 of set 5:mahajanga
# Processing 46 of set 5:bar harbor
# Another one!
# Processing 47 of set 5:fort nelson
# Processing 48 of set 5:corinto
# Processing 49 of set 5:la ronge
# Processing 50 of set 5:jutai
# Processing 0 of set 6:watsa
# Processing 1 of set 6:roatan
# Processing 2 of set 6:milazzo
# Processing 3 of set 6:miles city
# Processing 4 of set 6:sisimiut
# Processing 5 of set 6:los llanos de aridane
# Processing 6 of set 6:kasongo-lunda
# Processing 7 of set 6:berlevag
# Processing 8 of set 6:trinidad
# Processing 9 of set 6:baghdad
# Processing 10 of set 6:sakakah
# Processing 11 of set 6:nuuk
# Processing 12 of set 6:wanning
# Processing 13 of set 6:amazar
# Another one!
# Processing 14 of set 6:denpasar
# Processing 15 of set 6:talas
# Processing 16 of set 6:kaohsiung
# Processing 17 of set 6:axim
# Processing 18 of set 6:boguchany
# Processing 19 of set 6:mount isa
# Processing 20 of set 6:nanortalik
# Another one!
# Processing 21 of set 6:mae hong son
# Processing 22 of set 6:skjervoy
# Processing 23 of set 6:puerto madryn
# Processing 24 of set 6:elizabeth city
# Processing 25 of set 6:teluk nibung
# Processing 26 of set 6:anadyr
# Processing 27 of set 6:talcahuano
# Processing 28 of set 6:acapulco
# Processing 29 of set 6:coolum beach
# Processing 30 of set 6:plettenberg bay
# Processing 31 of set 6:mkushi
# Processing 32 of set 6:hendek
# Another one!
# Processing 33 of set 6:gravelbourg
# Processing 34 of set 6:hayden
# Processing 35 of set 6:bambous virieux
# Processing 36 of set 6:key west
# Processing 37 of set 6:mokrous
# Processing 38 of set 6:mareeba
# Processing 39 of set 6:xuddur
# Processing 40 of set 6:port blair
# Processing 41 of set 6:baragaon
# Processing 42 of set 6:the pas
# Processing 43 of set 6:angoche
# Processing 44 of set 6:turukhansk
# Processing 45 of set 6:marawi
# Processing 46 of set 6:guangyuan
# Processing 47 of set 6:xining
# Processing 48 of set 6:rocha
# Processing 49 of set 6:norman wells
# Processing 50 of set 6:turayf
# Processing 0 of set 7:coro
# Processing 1 of set 7:vao
# Processing 2 of set 7:kaitangata
# Processing 3 of set 7:varzea grande
# Processing 4 of set 7:ilulissat
# Processing 5 of set 7:srednekolymsk
# Processing 6 of set 7:asosa
# Processing 7 of set 7:vallenar
# Processing 8 of set 7:ust-maya
# Processing 9 of set 7:kainantu
# Processing 10 of set 7:kloulklubed
# Processing 11 of set 7:krasnoselkup
# Processing 12 of set 7:teahupoo
# Processing 13 of set 7:sur
# Processing 14 of set 7:kumo
# Processing 15 of set 7:bathsheba
# Another one!
# Processing 16 of set 7:sawakin
# Processing 17 of set 7:mangai
# Processing 18 of set 7:bosaso
# Processing 19 of set 7:saint-jean-de-maurienne
# Processing 20 of set 7:gongzhuling
# Processing 21 of set 7:dong hoi
# Processing 22 of set 7:kirakira
# Processing 23 of set 7:midland
# Processing 24 of set 7:udachnyy
# Processing 25 of set 7:itamaraca
# Processing 26 of set 7:meulaboh
# Processing 27 of set 7:spirit river
# Processing 28 of set 7:porbandar
# Processing 29 of set 7:half moon bay
# Another one!
# Processing 30 of set 7:batemans bay
# Processing 31 of set 7:batagay
# Processing 32 of set 7:shelburne
# Processing 33 of set 7:fort morgan
# Processing 34 of set 7:verkhnevilyuysk
# Processing 35 of set 7:ahipara
# Processing 36 of set 7:chara
# Processing 37 of set 7:tarauaca
# Processing 38 of set 7:nara
# Another one!
# Processing 39 of set 7:guilin
# Processing 40 of set 7:shenzhen
# Processing 41 of set 7:jojoima
# Processing 42 of set 7:olinda
# Processing 43 of set 7:najran
# Processing 44 of set 7:pitimbu
# Processing 45 of set 7:miyazu
# Processing 46 of set 7:fortuna
# Processing 47 of set 7:harstad
# Processing 48 of set 7:lai
# Processing 49 of set 7:haverfordwest
# Processing 50 of set 7:lompoc
# Processing 0 of set 8:muisne
# Processing 1 of set 8:sauda
# Another one!
# Processing 2 of set 8:ciudad bolivar
# Processing 3 of set 8:hushitai
# Processing 4 of set 8:makushino
# Processing 5 of set 8:ati
# Processing 6 of set 8:porosozero
# Processing 7 of set 8:georgiyevka
# Processing 8 of set 8:hami
# Processing 9 of set 8:yershichi
# Processing 10 of set 8:sharjah
# Processing 11 of set 8:auki
# Another one!
# Processing 12 of set 8:malindi
# Another one!
# Processing 13 of set 8:pacific grove
# Processing 14 of set 8:severo-kurilsk
# Processing 15 of set 8:coquimbo
# Processing 16 of set 8:fjerritslev
# Processing 17 of set 8:teknaf
# Processing 18 of set 8:veraval
# Processing 19 of set 8:smithers
# Processing 20 of set 8:talnakh
# Processing 21 of set 8:leczyca
# Processing 22 of set 8:sao francisco do sul
# Processing 23 of set 8:shitkino
# Processing 24 of set 8:dingle
# Processing 25 of set 8:taft
# Processing 26 of set 8:maxixe
# Processing 27 of set 8:behbahan
# Processing 28 of set 8:waw
# Processing 29 of set 8:teya
# Processing 30 of set 8:capreol
# Processing 31 of set 8:guerrero negro
# Processing 32 of set 8:solnechnyy
# Processing 33 of set 8:leningradskiy
# Processing 34 of set 8:san roque
# Processing 35 of set 8:san andres
# Another one!
# Processing 36 of set 8:collie
# Processing 37 of set 8:terney
# Processing 38 of set 8:narsaq
# Processing 39 of set 8:saint-francois
# Processing 40 of set 8:teguldet
# Processing 41 of set 8:alofi
# Processing 42 of set 8:langxiang
# Processing 43 of set 8:chapais
# Processing 44 of set 8:sogne
# Processing 45 of set 8:ostrovnoy
# Processing 46 of set 8:lebanon
# Processing 47 of set 8:seydi
# Processing 48 of set 8:fergus falls
# Processing 49 of set 8:armidale
# Processing 50 of set 8:comodoro rivadavia
# Processing 0 of set 9:santa flavia
# Processing 1 of set 9:teplodar
# Processing 2 of set 9:salinopolis
# Processing 3 of set 9:tres arroyos
# Processing 4 of set 9:ouallam
# Processing 5 of set 9:magnitka
# Processing 6 of set 9:vila franca do campo
# Processing 7 of set 9:maceio
# Processing 8 of set 9:mana
# Processing 9 of set 9:buala
# Processing 10 of set 9:seoul
# Processing 11 of set 9:glace bay
# Processing 12 of set 9:tuy hoa
# Processing 13 of set 9:severodvinsk
# Processing 14 of set 9:parana
# Processing 15 of set 9:cockburn town
# Processing 16 of set 9:goderich
# Another one!
# Processing 17 of set 9:dehloran
# Processing 18 of set 9:malanje
# Processing 19 of set 9:verin
# Processing 20 of set 9:taltal
# Processing 21 of set 9:anloga
# Processing 22 of set 9:isangel
# Processing 23 of set 9:ust-nera
# Processing 24 of set 9:porto novo
# Processing 25 of set 9:richards bay
# Processing 26 of set 9:tefe
# Processing 27 of set 9:bubaque
# Processing 28 of set 9:bekhtery
# Processing 29 of set 9:chimoio
# Processing 30 of set 9:brae
# Processing 31 of set 9:praia da vitoria
# Processing 32 of set 9:namalenga
# Processing 33 of set 9:sioux lookout
# Processing 34 of set 9:hanko
# Processing 35 of set 9:saint-joseph
# Another one!
# Processing 36 of set 9:nova vicosa
# Processing 37 of set 9:chulman
# Processing 38 of set 9:kholm
# Processing 39 of set 9:gunnedah
# Processing 40 of set 9:mandalgovi
# Processing 41 of set 9:karratha
# Processing 42 of set 9:lorengau
# Processing 43 of set 9:kokomo
# Processing 44 of set 9:saurimo
# Processing 45 of set 9:caraballeda
# Processing 46 of set 9:saldanha
# Processing 47 of set 9:matara
# Processing 48 of set 9:nouadhibou
# Processing 49 of set 9:barcelos
# Processing 50 of set 9:prince albert
# Processing 0 of set 10:palma
# Processing 1 of set 10:luderitz
# Processing 2 of set 10:kushiro
# Processing 3 of set 10:mezen
# Processing 4 of set 10:gorin
# Processing 5 of set 10:huzhou
# Processing 6 of set 10:igarka
# Processing 7 of set 10:doka
# Processing 8 of set 10:polyarnyy
# Processing 9 of set 10:adoni
# Processing 10 of set 10:arica
# Processing 11 of set 10:copperas cove
# Processing 12 of set 10:manggar
# Processing 13 of set 10:ponta delgada
# Processing 14 of set 10:shinjo
# Processing 15 of set 10:porto de moz
# Processing 16 of set 10:rantepao
# Processing 17 of set 10:varna
# Processing 18 of set 10:lewistown
# Processing 19 of set 10:necochea
# Processing 20 of set 10:tsiroanomandidy
# Processing 21 of set 10:concordia
# Processing 22 of set 10:erzin
# Processing 23 of set 10:haines junction
# Processing 24 of set 10:baruun-urt
# Processing 25 of set 10:sandwick
# Processing 26 of set 10:xiazhen
# Processing 27 of set 10:deputatskiy
# Processing 28 of set 10:nizwa
# Another one!
# Processing 29 of set 10:paita
# Another one!
# Processing 30 of set 10:piacabucu
# Processing 31 of set 10:milas
# Processing 32 of set 10:mananjary
# Processing 33 of set 10:gander
# Processing 34 of set 10:fuyang
# Processing 35 of set 10:morros
# Processing 36 of set 10:nevel
# Processing 37 of set 10:katsina
# Processing 38 of set 10:kaeo
# Processing 39 of set 10:north platte
# Processing 40 of set 10:canutama
# Processing 41 of set 10:margate
# Processing 42 of set 10:poum
# Processing 43 of set 10:lerwick
# Processing 44 of set 10:rameswaram
# Processing 45 of set 10:matay
# Processing 46 of set 10:vanimo
# Processing 47 of set 10:aitape
# Another one!
# Processing 48 of set 10:naryan-mar
# Processing 49 of set 10:awbari
# Another one!
# Processing 50 of set 10:bougouni
# Processing 0 of set 11:lanzhou
# Processing 1 of set 11:ancud
# Processing 2 of set 11:huacho
# Processing 3 of set 11:eloszallas
# Processing 4 of set 11:luino
# Processing 5 of set 11:oktyabrskiy
# Processing 6 of set 11:hervey bay
# Processing 7 of set 11:minot
# Processing 8 of set 11:medford
# Processing 9 of set 11:cortes
# Processing 10 of set 11:shawville
# Processing 11 of set 11:tiznit
# Processing 12 of set 11:nizhniy kuranakh
# Processing 13 of set 11:chepo
# Processing 14 of set 11:prince rupert
# Processing 15 of set 11:am timan
# Processing 16 of set 11:den helder
# Processing 17 of set 11:tura
# Processing 18 of set 11:shuya
# Processing 19 of set 11:cotonou
# Processing 20 of set 11:amahai
# Processing 21 of set 11:evensk
# Processing 22 of set 11:balkanabat
# Another one!
# Processing 23 of set 11:manacapuru
# Processing 24 of set 11:melfort
# Processing 25 of set 11:perigueux
# Processing 26 of set 11:ada
# Processing 27 of set 11:hambantota
# Processing 28 of set 11:inirida
# Processing 29 of set 11:mosquera
# Another one!
# Processing 30 of set 11:kysyl-syr
# Another one!
# Processing 31 of set 11:eyl
# Processing 32 of set 11:launceston
# Processing 33 of set 11:abaza
# Processing 34 of set 11:port lincoln
# Processing 35 of set 11:lykhivka
# Processing 36 of set 11:qostanay
# Processing 37 of set 11:inhambane
# Processing 38 of set 11:kajaani
# Processing 39 of set 11:disna
# Processing 40 of set 11:moscow
# Processing 41 of set 11:tatarskaya pishlya
# Processing 42 of set 11:thinadhoo
# Processing 43 of set 11:fare
# Processing 44 of set 11:nadym
# Processing 45 of set 11:emure
# Processing 46 of set 11:derzhavinsk
# Processing 47 of set 11:miri
# Processing 48 of set 11:adeje
# Processing 49 of set 11:brigantine
# Another one!
# Processing 50 of set 11:baykit
# Another one!
# Processing 0 of set 12:holme
# Processing 1 of set 12:janauba
# Processing 2 of set 12:malpur
# Processing 3 of set 12:sinjai
# Processing 4 of set 12:atocha
# Processing 5 of set 12:rawson
# Processing 6 of set 12:aguas formosas
# Processing 7 of set 12:dali
# Processing 8 of set 12:izvoru berheciului
# Processing 9 of set 12:pasco
# Processing 10 of set 12:yangjiang
# Processing 11 of set 12:barra do garcas
# -------------------------------
# Ending Data Retrieval

# %%
new_weather_df=pd.DataFrame({"City":new_city,
                           "Lat":lat,
                           "Lng":lng,
                           "Max Temp":max_temp,
                           "Humidity":humidity,
                           "Cloudiness":cloudiness,
                           "Wind Speed":wind_speed,
                           "Country":country,
                           "Date":date})
new_weather_df.head()
# Out:
#        City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Khatanga  71.97  102.50     52.03        56          59        6.29
# 1     Mahon  39.89    4.27     75.20        83           5        5.82
# 2      Asău  46.43   26.40     60.01        87           0        2.73
# 3    Broome  42.25  -75.83     71.01        73           1        4.70
# 4   Rikitea -23.12 -134.97     70.05        75          65       22.93
#
#   Country        Date
# 0      RU  1597117755
# 1      ES  1597117755
# 2      RO  1597117756
# 3      US  1597117756
# 4      PF  1597117756

# %%
new_weather_df.count()
# Out:
# City          572
# Lat           572
# Lng           572
# Max Temp      572
# Humidity      572
# Cloudiness    572
# Wind Speed    572
# Country       572
# Date          572
# dtype: int64

# %%
new_weather_df.to_csv("../output_data/weather.csv", index=False, header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
new_weather2_df=new_weather_df.loc[new_weather_df["Humidity"]<=100]
new_weather2_df
# Out:
#                    City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0              Khatanga  71.97  102.50     52.03        56          59
# 1                 Mahon  39.89    4.27     75.20        83           5
# 2                  Asău  46.43   26.40     60.01        87           0
# 3                Broome  42.25  -75.83     71.01        73           1
# 4               Rikitea -23.12 -134.97     70.05        75          65
# ..                  ...    ...     ...       ...       ...         ...
# 567                Dali  25.70  100.18     67.10        80         100
# 568  Izvoru Berheciului  46.58   27.22     61.00       100          25
# 569               Pasco  28.29  -82.42     80.01        86          34
# 570           Yangjiang  21.85  111.97     91.00        64         100
# 571     Barra do Garças -15.89  -52.26     68.58        45           0
#
#      Wind Speed Country        Date
# 0          6.29      RU  1597117755
# 1          5.82      ES  1597117755
# 2          2.73      RO  1597117756
# 3          4.70      US  1597117756
# 4         22.93      PF  1597117756
# ..          ...     ...         ...
# 567        5.61      CN  1597117794
# 568        3.36      RO  1597117794
# 569        3.89      US  1597117794
# 570       10.80      CN  1597117794
# 571        3.15      BR  1597117643
#
# [572 rows x 9 columns]

# %%
new_weather2_df.describe()
# Out:
#               Lat        Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  572.000000  572.00000  572.000000  572.000000  572.000000  572.000000
# mean    22.211783   15.91500   68.296031   72.188811   48.293706    8.046259
# std     33.592282   89.34422   13.589859   18.713510   39.216911    4.926432
# min    -54.800000 -179.17000   30.200000    3.000000    0.000000    0.650000
# 25%     -5.135000  -62.30000   59.000000   62.000000    4.750000    4.470000
# 50%     26.815000   20.16000   69.530000   76.500000   41.000000    7.250000
# 75%     51.267500   92.92500   78.420000   87.000000   90.000000   10.830000
# max     78.220000  179.32000   97.000000  100.000000  100.000000   31.120000
#
#                Date
# count  5.720000e+02
# mean   1.597118e+09
# std    7.447239e+01
# min    1.597117e+09
# 25%    1.597118e+09
# 50%    1.597118e+09
# 75%    1.597118e+09
# max    1.597118e+09

# %%
#  Get the indices of cities that have humidity over 100%.
cities_indicies=new_weather_df.loc[new_weather_df["Humidity"]>100].index
cities_indicies
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".


humidity_out=new_weather_df["Humidity"]
humidity_out
quartiles= humidity_out.quantile([.25,.5,.75])
lowerquartile=quartiles[0.25]
upperquartile=quartiles[0.75]
iqr=upperquartile-lowerquartile
#Determine the outlier using the upper and lower bound
humidity_lower_bound=lowerquartile - (1.5*iqr)
humidity_upper_bound=upperquartile + (1.5*iqr)
print(f"{humidity_lower_bound} and {humidity_upper_bound} are the outliers")

outliers_indexes=new_weather_df.loc[(new_weather_df["Humidity"]<humidity_lower_bound) | (new_weather_df["Humidity"]>humidity_upper_bound)].index
outliers_indexes





clean_city_data = new_weather_df.drop(outliers_indexes,inplace=False)
clean_city_data
fresh_data=clean_city_data.sort_values("Humidity", ascending=False)
fresh_data
# Out:
# 24.5 and 124.5 are the outliers
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 95     Grindavik  63.84  -22.43     51.80       100          90       19.46
# 224         Laas  46.62   10.70     57.20       100          40        3.36
# 82        Bethel  41.37  -73.41     72.00       100           1        3.49
# 72   Yellowknife  62.46 -114.35     63.00       100          75        3.36
# 87      Klaksvík  62.23   -6.59     53.60       100          45        8.05
# ..           ...    ...     ...       ...       ...         ...         ...
# 221        Adrar  20.50  -10.07     91.56        30           4        7.70
# 191  Zhangjiakou  40.81  114.88     84.49        30          18        1.01
# 328      Midland  32.00 -102.08     91.40        29           0       17.22
# 385         Teya  60.38   92.63     81.66        28           0        4.68
# 288       Hayden  47.77 -116.79     77.00        27           1        8.05
#
#     Country        Date
# 95       IS  1597117762
# 224      IT  1597117770
# 82       US  1597117480
# 72       CA  1597117760
# 87       FO  1597117761
# ..      ...         ...
# 221      MR  1597117770
# 191      CN  1597117768
# 328      US  1597117496
# 385      RU  1597117781
# 288      US  1597117775
#
# [559 rows x 9 columns]

# %%
# Extract relevant fields from the data frame
extract_data=clean_city_data[["Lat","Max Temp","Humidity","Cloudiness","Wind Speed"]]
extract_data
# Out:
#        Lat  Max Temp  Humidity  Cloudiness  Wind Speed
# 0    71.97     52.03        56          59        6.29
# 1    39.89     75.20        83           5        5.82
# 2    46.43     60.01        87           0        2.73
# 3    42.25     71.01        73           1        4.70
# 4   -23.12     70.05        75          65       22.93
# ..     ...       ...       ...         ...         ...
# 567  25.70     67.10        80         100        5.61
# 568  46.58     61.00       100          25        3.36
# 569  28.29     80.01        86          34        3.89
# 570  21.85     91.00        64         100       10.80
# 571 -15.89     68.58        45           0        3.15
#
# [559 rows x 5 columns]

# %%
# Export the City_Data into a csv
extract_data.to_csv("../output_data/extra.csv",index=False, header=True)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(extract_data['Lat'],extract_data['Max Temp'])
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (f)')
plt.title("Latitude vs Max Temp")

#Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

#Save the plotted figure as .pngs
plt.savefig("../Images/Latitude vs Max Temp.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(extract_data['Lat'],extract_data['Humidity'])
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Latitude vs Humidity")
#Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

#Save the plotted figure as .pngs
plt.savefig("../Images/Latitude vs Humidity.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(extract_data['Lat'],extract_data['Cloudiness'])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Latitude vs Cloudiness")
#Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

#Save the plotted figure as .pngs
plt.savefig("../Images/Latitude vs Cloudiness.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(extract_data['Lat'],extract_data['Wind Speed'])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Latitude vs Wind Speed")
#Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

#Save the plotted figure as .pngs
plt.savefig("../Images/Latitude vs Wind Speed.png")

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern_hemisphere=extract_data.loc[extract_data["Lat"]>=0]
#northern_hemisphere.sort_values("Max Temp", ascending=True)
northern_hemisphere
# Out:
#        Lat  Max Temp  Humidity  Cloudiness  Wind Speed
# 0    71.97     52.03        56          59        6.29
# 1    39.89     75.20        83           5        5.82
# 2    46.43     60.01        87           0        2.73
# 3    42.25     71.01        73           1        4.70
# 9    63.75     41.00        86          75        1.30
# ..     ...       ...       ...         ...         ...
# 562  23.35     80.24        88         100        6.58
# 567  25.70     67.10        80         100        5.61
# 568  46.58     61.00       100          25        3.36
# 569  28.29     80.01        86          34        3.89
# 570  21.85     91.00        64         100       10.80
#
# [393 rows x 5 columns]

# %%
southern_hemisphere=extract_data.loc[clean_city_data["Lat"]<0]
#southern_hemisphere.sort_values("Max Temp", ascending=True)
southern_hemisphere
# Out:
#        Lat  Max Temp  Humidity  Cloudiness  Wind Speed
# 4   -23.12     70.05        75          65       22.93
# 5    -1.27     78.80       100          40        2.24
# 6   -38.27     56.46        71         100       14.18
# 7   -53.15     32.00        90         100       14.99
# 8   -46.60     52.00        68          88       11.01
# ..     ...       ...       ...         ...         ...
# 563  -5.12     84.52        74           9        6.98
# 564 -20.93     38.70        50           0        3.71
# 565 -43.30     42.03        62           0       23.35
# 566 -17.08     64.60        94          92        1.63
# 571 -15.89     68.58        45           0        3.15
#
# [166 rows x 5 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
st.linregress(northern_hemisphere["Lat"],northern_hemisphere["Max Temp"])

x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared is: {rvalue**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title("Northern Hemisphere- Max Temp vs. Latitude Linear Regression")
plt.show()
plt.savefig("../Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# %matplotlib inline
print(f"There is a moderate positive correlation between Max Temp and Latitude Linear Regression(Northern Hemisphere)")
# Out:
# The r-squared is: 0.4933914607127037
# There is a moderate positive correlation between Max Temp and Latitude Linear Regression(Northern Hemisphere)

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
st.linregress(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared is: {rvalue**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title("Southern Hemisphere- Max Temp vs. Latitude Linear Regression")
plt.show()
plt.savefig("../Images/Sorthern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# %matplotlib inline
print(f"There is a moderate positive correlation between Max Temp and Latitude Linear Regression(Southern Hemisphere)")
# Out:
# The r-squared is: 0.6162157084657056
# There is a moderate positive correlation between Max Temp and Latitude Linear Regression(Southern Hemisphere)

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
st.linregress(northern_hemisphere["Lat"],northern_hemisphere["Humidity"])

x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared is: {rvalue**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Northern Hemisphere- Humidity vs. Latitude Linear Regression")
plt.show()
# %matplotlib inline
plt.savefig("../Images/Northern Hemisphere - Humidity vs. Latitude Linear Regression.png")
print(f"There is a weak positive correlation between Humidity and Latitude Linear Regression(Northern Hemisphere)")
# Out:
# The r-squared is: 0.004008810141784869
# There is a weak positive correlation between Humidity and Latitude Linear Regression(Northern Hemisphere)

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
st.linregress(southern_hemisphere["Lat"],southern_hemisphere["Humidity"])

x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared is: {rvalue**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Southern Hemisphere- Humidity vs. Latitude Linear Regression")
plt.show()
plt.savefig("../Images/Sorthern Hemisphere - Humidity vs. Latitude Linear Regression.png")
# %matplotlib inline
print(f"There is a weak positive correlation between Humidity and Latitude Linear Regression(Southern Hemisphere)")
# Out:
# The r-squared is: 0.01959677326613366
# There is a weak positive correlation between Humidity and Latitude Linear Regression(Southern Hemisphere)

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
st.linregress(northern_hemisphere["Lat"],northern_hemisphere["Cloudiness"])

x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared is: {rvalue**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Northern Hemisphere- Cloudiness vs. Latitude Linear Regression")
plt.show()
plt.savefig("../Images/Northern Hemisphere - Cloudiness vs. Latitude Linear Regression.png")
# %matplotlib inline
print(f"There is a weak positive correlation between Cloudiness and Latitude Linear Regression(Northern Hemisphere)")
# Out:
# The r-squared is: 0.004184141116264917
# There is a weak positive correlation between Cloudiness and Latitude Linear Regression(Northern Hemisphere)

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
st.linregress(southern_hemisphere["Lat"],southern_hemisphere["Cloudiness"])

x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared is: {rvalue**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Southern Hemisphere- Cloudiness vs. Latitude Linear Regression")
plt.show()
plt.savefig("../Images/Southern Hemisphere - Cloudiness vs. Latitude Linear Regression.png")
# %matplotlib inline
print(f"There is a weak positive correlation between Cloudiness and Latitude Linear Regression(Southern Hemisphere)")
# Out:
# The r-squared is: 0.0077378663942837935
# There is a weak positive correlation between Cloudiness and Latitude Linear Regression(Southern Hemisphere)

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
st.linregress(northern_hemisphere["Lat"],northern_hemisphere["Wind Speed"])

x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared is: {rvalue**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title("Northern Hemisphere- Wind Speed vs. Latitude Linear Regression")
plt.show()
plt.savefig("../Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# %matplotlib inline
print(f"There is a weak positive correlation between Wind speed and Latitude Linear Regression(Northern Hemisphere)")
# Out:
# The r-squared is: 0.0005168284414110663
# There is a weak positive correlation between Wind speed and Latitude Linear Regression(Northern Hemisphere)

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
st.linregress(southern_hemisphere["Lat"],southern_hemisphere["Wind Speed"])

x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared is: {rvalue**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title("Southern Hemisphere- Wind Speed vs. Latitude Linear Regression")
plt.show()
plt.savefig("../Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# %matplotlib inline
print(f"There is a weak positive correlation between Wind speed and Latitude Linear Regression(Southern Hemisphere)")
# Out:
# The r-squared is: 0.1703693458321285
# There is a weak positive correlation between Wind speed and Latitude Linear Regression(Southern Hemisphere)
